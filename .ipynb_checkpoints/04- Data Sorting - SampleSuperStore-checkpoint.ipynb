# %% [markdown]
# # Sample Super Store Part 4 - Data Pivot
# ## This is a sample notebook from the Sample Super Store Dataset
#
# This notebook is intended to give a brief overview on how to explore dataset, which in this case is the Ssample Super Store dataset, which I believe to be a fictional ecommerce company. With that being said, let's try to explore certain data angle with the Panda's library for Python using the Jupyter Notebook.
#
# ### Importing the required libraries into the notebook.

# %% [markdown]
# # Importing packages
# import pandas as pd
# import numpy as np

# %%
# Importing packages
import pandas as pd
import numpy as np

# %% [markdown]
# # Sorting

# %% [markdown]
# ### Let's try to read the CSV record
# The following code would imply these instructions
# - df_orders = is the name of the variable, that will be using throughout the example of this tutorial.
# - pd = stands for Panda
# - .read_csv = is a method within to read the CSV file.

# %%
df_cleaning = pd.read_csv('df_cleaning.csv')

# %%
# Set the total rows and columns default numbers.
pd.set_option('display.max_columns', 23)
pd.set_option('display.max_rows', 5)

# %%
df_cleaning.head(3)
# Out:
#    RowID         OrderID   OrderDate    ShipDate      ShipMode CustomerID  \
# 0      1  CA-2017-152156  2017-11-08  2017-11-11  Second Class   CG-12520
# 1      2  CA-2017-152156  2017-11-08  2017-11-11  Second Class   CG-12520
# 2      3  CA-2017-138688  2017-06-12  2017-06-16  Second Class   DV-13045
#
#       CustomerName    Segment        Country         City       State  \
# 0      Claire Gute   Consumer  United States    Henderson    Kentucky
# 1      Claire Gute   Consumer  United States    Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States  Los Angeles  California
#
#    PostalCode Region        ProductID         Category SubCategory  \
# 0     42420.0  South  FUR-BO-10001798        Furniture   Bookcases
# 1     42420.0  South  FUR-CH-10000454        Furniture      Chairs
# 2     90036.0   West  OFF-LA-10000240  Office Supplies      Labels
#
#                                          ProductName   Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.96       2.0
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.94       3.0
# 2  Self-Adhesive Address Labels for Typewriters b...   14.62       2.0
#
#    Discount    Profit   Revenue  NetPrice
# 0       0.0   41.9136  220.0464   89.0664
# 1       0.0  219.5820  512.3580   97.5920
# 2       0.0    6.8714    7.7486    0.4386

# %%
# Let's print the columns (features) names.
df_cleaning.columns
# Out:
# Index(['RowID', 'OrderID', 'OrderDate', 'ShipDate', 'ShipMode', 'CustomerID',
#        'CustomerName', 'Segment', 'Country', 'City', 'State', 'PostalCode',
#        'Region', 'ProductID', 'Category', 'SubCategory', 'ProductName',
#        'Sales', 'Quantity', 'Discount', 'Profit', 'Revenue', 'NetPrice'],
#       dtype='object')

# %%
# Let's print the columns data types.
df_cleaning.dtypes
# Out:
# RowID         int64
# OrderID      object
#              ...
# Revenue     float64
# NetPrice    float64
# Length: 23, dtype: object

# %%
df_cleaning.loc[df_cleaning['Category'] == 'Office Supplies']
# Out:
#       RowID         OrderID   OrderDate    ShipDate        ShipMode  \
# 2         3  CA-2017-138688  2017-06-12  2017-06-16    Second Class
# 4         5  US-2016-108966  2016-10-11  2016-10-18  Standard Class
# ...     ...             ...         ...         ...             ...
# 9981   9993  CA-2018-121258  2018-02-26  2018-03-03  Standard Class
# 9982   9994  CA-2018-119914  2018-05-04  2018-05-09    Second Class
#
#      CustomerID     CustomerName    Segment        Country             City  \
# 2      DV-13045  Darrin Van Huff  Corporate  United States      Los Angeles
# 4      SO-20335   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# ...         ...              ...        ...            ...              ...
# 9981   DB-13060      Dave Brooks   Consumer  United States       Costa Mesa
# 9982   CC-12220     Chris Cortes   Consumer  United States      Westminster
#
#            State  PostalCode Region        ProductID         Category  \
# 2     California     90036.0   West  OFF-LA-10000240  Office Supplies
# 4        Florida     33311.0  South  OFF-ST-10000760  Office Supplies
# ...          ...         ...    ...              ...              ...
# 9981  California     92627.0   West  OFF-PA-10004041  Office Supplies
# 9982  California     92683.0   West  OFF-AP-10002684  Office Supplies
#
#      SubCategory                                        ProductName    Sales  \
# 2         Labels  Self-Adhesive Address Labels for Typewriters b...   14.620
# 4        Storage                     Eldon Fold 'N Roll Cart System   22.368
# ...          ...                                                ...      ...
# 9981       Paper  It's Hot Message Books with Stickers, 2 3/4" x 5"   29.600
# 9982  Appliances  Acco 7-Outlet Masterpiece Power Center, Wihtou...  243.160
#
#       Quantity  Discount   Profit   Revenue  NetPrice
# 2          2.0       0.0   6.8714    7.7486   0.43860
# 4          2.0       0.2   2.5164   19.8516   6.93408
# ...        ...       ...      ...       ...       ...
# 9981       4.0       0.0  13.3200   16.2800   0.74000
# 9982       2.0       0.0  72.9480  170.2120  48.63200
#
# [6020 rows x 23 columns]

# %%
df_cleaning.loc[df_cleaning['Category'] == 'Furniture']
# Out:
#       RowID         OrderID   OrderDate    ShipDate        ShipMode  \
# 0         1  CA-2017-152156  2017-11-08  2017-11-11    Second Class
# 1         2  CA-2017-152156  2017-11-08  2017-11-11    Second Class
# ...     ...             ...         ...         ...             ...
# 9978   9990  CA-2015-110422  2015-01-21  2015-01-23    Second Class
# 9979   9991  CA-2018-121258  2018-02-26  2018-03-03  Standard Class
#
#      CustomerID      CustomerName   Segment        Country        City  \
# 0      CG-12520       Claire Gute  Consumer  United States   Henderson
# 1      CG-12520       Claire Gute  Consumer  United States   Henderson
# ...         ...               ...       ...            ...         ...
# 9978   TB-21400  Tom Boeckenhauer  Consumer  United States       Miami
# 9979   DB-13060       Dave Brooks  Consumer  United States  Costa Mesa
#
#            State  PostalCode Region        ProductID   Category  SubCategory  \
# 0       Kentucky     42420.0  South  FUR-BO-10001798  Furniture    Bookcases
# 1       Kentucky     42420.0  South  FUR-CH-10000454  Furniture       Chairs
# ...          ...         ...    ...              ...        ...          ...
# 9978     Florida     33180.0  South  FUR-FU-10001889  Furniture  Furnishings
# 9979  California     92627.0   West  FUR-FU-10000747  Furniture  Furnishings
#
#                                             ProductName    Sales  Quantity  \
# 0                     Bush Somerset Collection Bookcase  261.960       2.0
# 1     Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.940       3.0
# ...                                                 ...      ...       ...
# 9978                             Ultra Door Pull Handle   25.248       3.0
# 9979  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.960       2.0
#
#       Discount    Profit   Revenue  NetPrice
# 0          0.0   41.9136  220.0464  89.06640
# 1          0.0  219.5820  512.3580  97.59200
# ...        ...       ...       ...       ...
# 9978       0.2    4.1028   21.1452   4.54464
# 9979       0.0   15.6332   76.3268  30.34680
#
# [2119 rows x 23 columns]

# %%
df_cleaning.loc[(df_cleaning['Category'] == 'Furniture') & (df_cleaning['SubCategory'] == 'Bookcases')]
# Out:
#       RowID         OrderID   OrderDate    ShipDate        ShipMode  \
# 0         1  CA-2017-152156  2017-11-08  2017-11-11    Second Class
# 27       28  US-2016-150630  2016-09-17  2016-09-21  Standard Class
# ...     ...             ...         ...         ...             ...
# 9920   9932  CA-2016-104948  2016-11-13  2016-11-17  Standard Class
# 9951   9963  CA-2016-168088  2016-03-19  2016-03-22     First Class
#
#      CustomerID      CustomerName      Segment        Country            City  \
# 0      CG-12520       Claire Gute     Consumer  United States       Henderson
# 27     TB-21520   Tracy Blumstein     Consumer  United States    Philadelphia
# ...         ...               ...          ...            ...             ...
# 9920   KH-16510     Keith Herrera     Consumer  United States  San Bernardino
# 9951   CM-12655  Corinna Mitchell  Home Office  United States         Houston
#
#              State  PostalCode   Region        ProductID   Category  \
# 0         Kentucky     42420.0    South  FUR-BO-10001798  Furniture
# 27    Pennsylvania     19140.0     East  FUR-BO-10004834  Furniture
# ...            ...         ...      ...              ...        ...
# 9920    California     92404.0     West  FUR-BO-10004357  Furniture
# 9951         Texas     77041.0  Central  FUR-BO-10004218  Furniture
#
#      SubCategory                                        ProductName  \
# 0      Bookcases                  Bush Somerset Collection Bookcase
# 27     Bookcases  Riverside Palais Royal Lawyers Bookcase, Royal...
# ...          ...                                                ...
# 9920   Bookcases     O'Sullivan Living Dimensions 3-Shelf Bookcases
# 9951   Bookcases  Bush Heritage Pine Collection 5-Shelf Bookcase...
#
#           Sales  Quantity  Discount     Profit    Revenue    NetPrice
# 0      261.9600       2.0      0.00    41.9136   220.0464   89.066400
# 27    3083.4300       7.0      0.50 -1665.0522  4748.4822  458.109600
# ...         ...       ...       ...        ...        ...         ...
# 9920   683.3320       4.0      0.15   -40.1960   723.5280  162.291350
# 9951   383.4656       4.0      0.32   -67.6704   451.1360   88.197088
#
# [227 rows x 23 columns]

# %%
df_Furniture_Bookcases = df_cleaning.loc[(df_cleaning['Category'] == 'Furniture') & (df_cleaning['SubCategory'] == 'Bookcases')]

# %%
df_Furniture_Bookcases
# Out:
#       RowID         OrderID   OrderDate    ShipDate        ShipMode  \
# 0         1  CA-2017-152156  2017-11-08  2017-11-11    Second Class
# 27       28  US-2016-150630  2016-09-17  2016-09-21  Standard Class
# ...     ...             ...         ...         ...             ...
# 9920   9932  CA-2016-104948  2016-11-13  2016-11-17  Standard Class
# 9951   9963  CA-2016-168088  2016-03-19  2016-03-22     First Class
#
#      CustomerID      CustomerName      Segment        Country            City  \
# 0      CG-12520       Claire Gute     Consumer  United States       Henderson
# 27     TB-21520   Tracy Blumstein     Consumer  United States    Philadelphia
# ...         ...               ...          ...            ...             ...
# 9920   KH-16510     Keith Herrera     Consumer  United States  San Bernardino
# 9951   CM-12655  Corinna Mitchell  Home Office  United States         Houston
#
#              State  PostalCode   Region        ProductID   Category  \
# 0         Kentucky     42420.0    South  FUR-BO-10001798  Furniture
# 27    Pennsylvania     19140.0     East  FUR-BO-10004834  Furniture
# ...            ...         ...      ...              ...        ...
# 9920    California     92404.0     West  FUR-BO-10004357  Furniture
# 9951         Texas     77041.0  Central  FUR-BO-10004218  Furniture
#
#      SubCategory                                        ProductName  \
# 0      Bookcases                  Bush Somerset Collection Bookcase
# 27     Bookcases  Riverside Palais Royal Lawyers Bookcase, Royal...
# ...          ...                                                ...
# 9920   Bookcases     O'Sullivan Living Dimensions 3-Shelf Bookcases
# 9951   Bookcases  Bush Heritage Pine Collection 5-Shelf Bookcase...
#
#           Sales  Quantity  Discount     Profit    Revenue    NetPrice
# 0      261.9600       2.0      0.00    41.9136   220.0464   89.066400
# 27    3083.4300       7.0      0.50 -1665.0522  4748.4822  458.109600
# ...         ...       ...       ...        ...        ...         ...
# 9920   683.3320       4.0      0.15   -40.1960   723.5280  162.291350
# 9951   383.4656       4.0      0.32   -67.6704   451.1360   88.197088
#
# [227 rows x 23 columns]
